# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejaswini-08-2005/NLP/blob/main/Lab_Assignment_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install libraries (only needed once per runtime)
# !pip install nltk spacy

# Import libraries
import nltk
import spacy

# Download NLTK resources
nltk.download('punkt')

# Load spaCy English model
# !python -m spacy download en_core_web_sm
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 39.8 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Example text (you can replace this with any snippet)
text = """The sun rises in the east and sets in the west.
It brings light, warmth, and hope to the world every day."""
print(text)
# Out:
# The sun rises in the east and sets in the west.
# It brings light, warmth, and hope to the world every day.

# %%
# Using NLTK word tokenizer
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt_tab') # Download the missing punkt_tab resource

words = word_tokenize(text)
print("Word Count:", len(words))
# Out:
# Word Count: 26
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
lower_text = text.lower()
print("Lowercase Text:\n", lower_text)
# Out:
# Lowercase Text:
#  the sun rises in the east and sets in the west.
# it brings light, warmth, and hope to the world every day.
